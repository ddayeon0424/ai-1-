# %%
print('Hello Python!!')
# Out:
# Hello Python!!

# %%
a=print('Hello Wolrd')
print(a)
# Out:
# Hello Wolrd
# None

# %%
def plus(a,b):
 c = a+b
 return c

ans=plus(4,3)

print(ans)
# Out:
# 7

# %%
def plus(a,b):
 c = a+b
 print(c)

ans=plus(4,3)

print(ans)
# Out:
# 7
# None

# %%
def plus(a,b):
 c = a+b
 return c

ans=4*plus(4,3)

print(ans)
# Out:
# 28

# %%
print('Hello','World!')
# Out:
# Hello World!

# %%
print('Hello'+'World!')
# Out:
# HelloWorld!

# %%
print(100)
# Out:
# 100

# %%
print(2+4)
# Out:
# 6

# %%
x = 100
y = 200

x ** 2
# Out:
# 10000

# %%
x = 105
y = 2.4

x // y
x % y
# Out:
# 1.8000000000000038

# %%
radius = 4.0
print('원의 반지름',radius)
print('원의 면적', 3.14 * radius * radius)
print('원의 둘레', 2.0 * 3.14 * radius)
# Out:
# 원의 반지름 4.0
# 원의 면적 50.24
# 원의 둘레 25.12
