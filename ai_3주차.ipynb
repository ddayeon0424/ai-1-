# %% [markdown]
# <a href="https://colab.research.google.com/github/ddayeon0424/ai-1-/blob/main/ai_3%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#LAB 3-1 1.
game_score = int(input("game_score 값을 입력하세요: "))
print(f"game_score = {game_score}")

if game_score >= 1000:
    print("당신은 고수입니다")
# Out:
# game_score 값을 입력하세요: 1300
# game_score = 1300
# 당신은 고수입니다

# %%
#LAB 3-1 2.
num_a = int(input("첫 번째 숫자를 입력하세요: "))
num_b = int(input("두 번째 숫자를 입력하세요: "))

if num_a == num_b:
    print("두 값이 일치합니다.")
# Out:
# 첫 번째 숫자를 입력하세요: 300
# 두 번째 숫자를 입력하세요: 300
# 두 값이 일치합니다.

# %%
#LAB 3-2 1.
n = int(input("정수를 입력하세요 : "))
print(f"n = {n}")

if n % 2 == 0:
    print(f"{n} 은(는) 짝수입니다.")
# Out:
# 정수를 입력하세요 : 50
# n = 50
# 50 은(는) 짝수입니다.

# %%
#LAB 3-2 2.
x = int(input("정수를 입력하세요 : "))
print(f"x = {x}")

if x > 0:
    print(f"{x} 은(는) 자연수입니다.")
# Out:
# 정수를 입력하세요 : -10
# x = -10

# %%
#LAB 3-3 1.
game_score = int(input("게임점수를 입력하시오 : "))
print(f"game_score = {game_score}")

if game_score >= 1000:
    print("고수입니다.")
else:
    print("입문자입니다.")
# Out:
# 게임점수를 입력하시오 : 1300
# game_score = 1300
# 고수입니다.

# %%
#LAB 3-3 2.
num1 = int(input("한 정수를 입력하시오 : "))
num2 = int(input("다른 정수를 입력하시오 : "))

if num1 == num2:
    print("두 값이 일치합니다.")
else:
    print("두 값이 일치하지 않습니다.")
# Out:
# 한 정수를 입력하시오 : 300
# 다른 정수를 입력하시오 : 300
# 두 값이 일치합니다.

# %%
#LAB 3-3 3.
is_adult = int(input("당신은 성인인가요(성인이면 1, 미성년이면 0): "))

if is_adult == 0:
    print("당신은 미성년자입니다.")
else:
    is_married = int(input("결혼을 하셨나요(기혼이면 1, 미혼이면 0): "))
    if is_married == 1:
        print("당신은 결혼한 성인입니다.")
    else:
        print("당신은 결혼하지 않은 성인입니다.")
# Out:
# 당신은 성인인가요(성인이면 1, 미성년이면 0): 1
# 결혼을 하셨나요(기혼이면 1, 미혼이면 0): 0
# 당신은 결혼하지 않은 성인입니다.

# %%
#LAB 3-4 1.
num = 2
print(num >= 1 and num <= 10)
# Out:
# True

# %%
#LAB 3-4 2.
age = 12
if age > 10 and age < 19:
    print('청소년입니다.')
# Out:
# 청소년입니다.

# %%
#LAB 3-5
speed = int(input("자동차의 속도를 입력하세요(단위 : km/h ): "))

if speed >= 100:
    print("고속")
elif speed >= 60:
    print("중속")
else:
    print("저속")
# Out:
# 자동차의 속도를 입력하세요(단위 : km/h ): 130
# 고속
